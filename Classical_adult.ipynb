# %%
# %reload_ext autoreload
# %autoreload 2
# !nvidia-smi
# Out:
# Mon Mar  9 15:29:32 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.95.02              Driver Version: 581.42         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 5090        On  |   00000000:01:00.0  On |                  N/A |
# | 30%   46C    P1            120W /  575W |    3708MiB /  32607MiB |     32%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A           44182      C   /python3.12                           N/A      |
# |    0   N/A  N/A           45146      C   /python3.12                           N/A      |
# |    0   N/A  N/A           47079      C   /python3.12                           N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import torch
if not hasattr(torch.Tensor, '_original_repr'):
    torch.Tensor._original_repr = torch.Tensor.__repr__
    torch.Tensor.__repr__ = lambda self: f"{self.shape} {torch.Tensor._original_repr(self)}"

import sys

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
import pennylane as qml
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score
import os
import time
from tqdm.notebook import tqdm # Use notebook version of tqdm
import matplotlib.pyplot as plt

# Custom local imports (Ensure these files are in the same directory)
import dataloader.adult_dataloader as adult_dataloader
import InputEmbeddings
import bias_calculation
from seed import set_seed
import models.quantum_circuits as quantum_circuits
import models.models as models

# Configure Plotting Style
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 8)

# %%
class Config:
    epochs : int = 500
    n_qubits : int = 7
    n_layers : int = 3
    hidden_dim : int = 8
    learning_rate : float = 1e-4
    batch_size : int = 512
    run_name : str = f"Qubits-{n_qubits}_Ang_TrnEbding"
    seed : int = 42
    device : str = 'cuda'
    dev =qml.device('default.qubit', wires=n_qubits) if device == 'cpu' else qml.device('lightning.qubit', wires=n_qubits)
    diff_method : str = "backprop" if device == 'cpu' else "adjoint"
cfg = Config()

# %%
# Ensure reproducibility
set_seed(cfg.seed)

cpu_count = os.cpu_count()
num_workers = 4 if cpu_count > 4 and cfg.device == 'cpu' else 0

print(f"Using device: {cfg.device}")
print(f"Number of CPU cores: {cpu_count}, Setting num_workers to: {num_workers}")
print(f"Hyperparameters: epochs={cfg.epochs}, n_qubits={cfg.n_qubits}, n_layers={cfg.n_layers}, lr={cfg.learning_rate}, batch_size={cfg.batch_size}, run_name={cfg.run_name}")
# Out:
# Using device: cuda
# Number of CPU cores: 24, Setting num_workers to: 0
# Hyperparameters: epochs=500, n_qubits=7, n_layers=3, lr=0.0001, batch_size=512, run_name=Qubits-7_Ang_TrnEbding

# %%
# Load and Preprocess Data
X_train, X_test, y_train, y_test, sens_train, sens_test = adult_dataloader.load_and_preprocess_data()

# Optional: Feature Engineering (Commented out in original)
# X_train, X_test = InputEmbeddings.apply_pca(X_train, X_test, n_qubits) 
# X_train, X_test, n_qubits = prepare_amplitude_encoding(X_train, X_test) 

# Convert to Tensors
X_train_t = torch.tensor(X_train, dtype=torch.float32).to(cfg.device)
y_train_t = torch.tensor(y_train, dtype=torch.float32).unsqueeze(1).to(cfg.device)

X_test_t = torch.tensor(X_test, dtype=torch.float32).to(cfg.device)
y_test_t = torch.tensor(y_test, dtype=torch.float32).unsqueeze(1).to(cfg.device)
sens_test_t = sens_test 

# Create DataLoader
train_dataset = TensorDataset(X_train_t, y_train_t)
train_loader = DataLoader(train_dataset, batch_size=cfg.batch_size, shuffle=True, num_workers=num_workers)

print(f"Data Loaded. Train shape: {X_train.shape}, Test shape: {X_test.shape}")
# Out:
# Loading and preprocessing data...
# Data Loaded. Train shape: (30162, 101), Test shape: (15060, 101)

# %%
from models.mlp import ClassicalMLP
from utils.misc import count_parameters
model = ClassicalMLP(
    input_dim=X_train.shape[1],
    hidden_dim=cfg.hidden_dim,
    ).to(cfg.device)
_ = count_parameters(model)
# Out:
# Total params: 897
# Train params: 897

# %%
optimizer = optim.AdamW(model.parameters(), lr=cfg.learning_rate)
criterion = nn.BCEWithLogitsLoss()

print(f"\nStarting mini-batch training (Batch Size: {cfg.batch_size}, Qubits: {cfg.n_qubits})")
start_train = time.time()

# Lists to store metrics for visualization
history_loss = []
history_acc = []

for epoch in range(cfg.epochs):
    model.train()
    total_loss = 0
    
    for batch_X, batch_y in train_loader:
        batch_X, batch_y = batch_X.to(cfg.device), batch_y.to(cfg.device)

        optimizer.zero_grad()
        outputs = model(batch_X)
        loss = criterion(outputs, batch_y)
        loss.backward()
        optimizer.step()

        # Record metrics per step
        current_loss = loss.item()
        total_loss += current_loss
            
        # Calculate batch accuracy
        preds = (torch.sigmoid(outputs) > 0.5).float()
        acc = (preds == batch_y).float().mean().item()
            
        history_loss.append(current_loss)
        history_acc.append(acc)

    
    avg_loss = total_loss / len(train_loader)
    if (epoch+1) % 10 == 0:
        model.eval()
        with torch.no_grad():
            test_outputs = model(X_test_t)
            # Store raw probabilities for visualization later
            test_probs = torch.sigmoid(test_outputs).cpu().numpy().flatten()
            predictions = (test_probs > 0.5).astype(float)
            y_test_numpy = y_test_t.cpu().numpy().flatten().astype(int)

        # Standard Accuracy
        acc = accuracy_score(y_test_numpy, predictions)
        print(f"Epoch {epoch+1} Average Loss: {avg_loss:.4f} | Test Accuracy: {acc:.4f}")
        model.train



print(f"Training time: {time.time() - start_train:.2f}s")
# Out:
# Starting mini-batch training (Batch Size: 512, Qubits: 7)
# Epoch 10 Average Loss: 0.5744 | Test Accuracy: 0.7607
# Epoch 20 Average Loss: 0.4233 | Test Accuracy: 0.8167
# Epoch 30 Average Loss: 0.3650 | Test Accuracy: 0.8343
# Epoch 40 Average Loss: 0.3512 | Test Accuracy: 0.8394
# Epoch 50 Average Loss: 0.3444 | Test Accuracy: 0.8424
# Epoch 60 Average Loss: 0.3408 | Test Accuracy: 0.8442
# Epoch 70 Average Loss: 0.3375 | Test Accuracy: 0.8458
# Epoch 80 Average Loss: 0.3341 | Test Accuracy: 0.8470
# Epoch 90 Average Loss: 0.3324 | Test Accuracy: 0.8467
# Epoch 100 Average Loss: 0.3298 | Test Accuracy: 0.8469
# Epoch 110 Average Loss: 0.3284 | Test Accuracy: 0.8473
# Epoch 120 Average Loss: 0.3277 | Test Accuracy: 0.8472
# Epoch 130 Average Loss: 0.3269 | Test Accuracy: 0.8477
# Epoch 140 Average Loss: 0.3266 | Test Accuracy: 0.8477
# Epoch 150 Average Loss: 0.3252 | Test Accuracy: 0.8478
# Epoch 160 Average Loss: 0.3248 | Test Accuracy: 0.8480
# Epoch 170 Average Loss: 0.3246 | Test Accuracy: 0.8483
# Epoch 180 Average Loss: 0.3247 | Test Accuracy: 0.8486
# Epoch 190 Average Loss: 0.3243 | Test Accuracy: 0.8482
# Epoch 200 Average Loss: 0.3245 | Test Accuracy: 0.8481
# Epoch 210 Average Loss: 0.3236 | Test Accuracy: 0.8483
# Epoch 220 Average Loss: 0.3232 | Test Accuracy: 0.8484
# Epoch 230 Average Loss: 0.3237 | Test Accuracy: 0.8487
# Epoch 240 Average Loss: 0.3235 | Test Accuracy: 0.8490
# Epoch 250 Average Loss: 0.3226 | Test Accuracy: 0.8490
# Epoch 260 Average Loss: 0.3227 | Test Accuracy: 0.8492
# Epoch 270 Average Loss: 0.3208 | Test Accuracy: 0.8490
# Epoch 280 Average Loss: 0.3216 | Test Accuracy: 0.8493
# Epoch 290 Average Loss: 0.3218 | Test Accuracy: 0.8492
# Epoch 300 Average Loss: 0.3218 | Test Accuracy: 0.8490
# Epoch 310 Average Loss: 0.3204 | Test Accuracy: 0.8494
# Epoch 320 Average Loss: 0.3200 | Test Accuracy: 0.8495
# Epoch 330 Average Loss: 0.3212 | Test Accuracy: 0.8499
# Epoch 340 Average Loss: 0.3201 | Test Accuracy: 0.8495
# Epoch 350 Average Loss: 0.3203 | Test Accuracy: 0.8499
# Epoch 360 Average Loss: 0.3192 | Test Accuracy: 0.8502
# Epoch 370 Average Loss: 0.3198 | Test Accuracy: 0.8505
# Epoch 380 Average Loss: 0.3205 | Test Accuracy: 0.8503
# Epoch 390 Average Loss: 0.3183 | Test Accuracy: 0.8509
# Epoch 400 Average Loss: 0.3189 | Test Accuracy: 0.8505
# Epoch 410 Average Loss: 0.3190 | Test Accuracy: 0.8507
# Epoch 420 Average Loss: 0.3184 | Test Accuracy: 0.8507
# Epoch 430 Average Loss: 0.3189 | Test Accuracy: 0.8507
# Epoch 440 Average Loss: 0.3177 | Test Accuracy: 0.8511
# Epoch 450 Average Loss: 0.3192 | Test Accuracy: 0.8510
# Epoch 460 Average Loss: 0.3185 | Test Accuracy: 0.8511
# Epoch 470 Average Loss: 0.3191 | Test Accuracy: 0.8509
# Epoch 480 Average Loss: 0.3178 | Test Accuracy: 0.8513
# Epoch 490 Average Loss: 0.3184 | Test Accuracy: 0.8515
# Epoch 500 Average Loss: 0.3186 | Test Accuracy: 0.8513
# Training time: 81.06s

# %%
model.eval()
print("\nTesting and evaluating bias...")

with torch.no_grad():
    test_outputs = model(X_test_t)
    # Store raw probabilities for visualization later
    test_probs = torch.sigmoid(test_outputs).cpu().numpy().flatten()
    predictions = (test_probs > 0.5).astype(float)
    y_test_numpy = y_test_t.cpu().numpy().flatten().astype(int)

# Standard Accuracy
acc = accuracy_score(y_test_numpy, predictions)

# Bias Metrics
dpd, prob_female, prob_male = bias_calculation.demographic_parity(predictions, sens_test_t)
eod, tpr_diff, fpr_diff = bias_calculation.equalized_odds(predictions, y_test_numpy, sens_test_t)

print("-" * 30)
print(f"Model accuracy (Accuracy): {acc:.4f}")
print("\n[Bias analysis (based on sex)]")
print(f"Probability of being predicted >50K for female: {prob_female:.4%}")
print(f"Probability of being predicted >50K for male: {prob_male:.4%}")
print(f"Demographic parity difference (DPD): {dpd:.4f}")
print(f"True Positive Rate difference (TPR diff): {tpr_diff:.4f}")
print(f"False Positive Rate difference (FPR diff): {fpr_diff:.4f}")
print(f"Equalized Odds difference (EOD): {eod:.4f}")
print("-" * 30)
# Out:
# Testing and evaluating bias...
# ------------------------------
# Model accuracy (Accuracy): 0.8513
#
# [Bias analysis (based on sex)]
# Probability of being predicted >50K for female: 8.7319%
# Probability of being predicted >50K for male: 26.3723%
# Demographic parity difference (DPD): 0.1764
# True Positive Rate difference (TPR diff): 0.0691
# False Positive Rate difference (FPR diff): 0.0734
# Equalized Odds difference (EOD): 0.0734
# ------------------------------

# %%
from utils.diagnostics import visualize_results

bias_dict = {
    'dpd': dpd,
    'tpr_diff': tpr_diff,
    'fpr_diff': fpr_diff,
    'eod': eod
}
visualize_results(history_loss, history_acc, test_probs, y_test_numpy, sens_test_t, bias_dict)
